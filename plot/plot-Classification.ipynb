# %% [markdown]
# # Find best parameters

# %% [markdown]
# ## TID ANN

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

def get_allfile(path):  
    all_file = []
    for f in os.listdir(path):  
        f_name = os.path.join(path, f)
        all_file.append(f_name)
    return all_file
    
roots = 'D:/code/EAST/grad/TIDigits_ANN'
file_list = get_allfile(roots)
matrix = np.zeros((10, 10))

for i in range(len(file_list)):
    x = int(float(file_list[i].split('_')[-2]) * 10) - 1

    y = int(float(file_list[i].split('_')[-1]) * 5) - 1

    f = np.loadtxt(os.path.join(file_list[i], 'testacc.txt'))
    matrix[x, y] = f[:,1].max()
print(matrix.max())
print(matrix)
print(np.where(matrix==matrix.max()))
print(matrix[5,9])
plt.imshow(matrix[:,:], cmap='rainbow')
plt.colorbar()
plt.show()
# Out:
# 81.51041666666667
# [[15.36458333 15.36458333 15.36458333 15.36458333 70.3125     15.625
#   15.625      15.625      15.625      15.88541667]
#  [19.27083333 20.83333333 22.91666667 30.98958333 78.125      54.94791667
#   38.02083333 34.63541667 26.5625     21.61458333]
#  [61.97916667 64.58333333 68.48958333 74.73958333 80.46875    80.98958333
#   78.38541667 75.         73.95833333 72.65625   ]
#  [79.6875     80.98958333 79.94791667 80.46875    81.25       80.98958333
#   80.72916667 80.72916667 80.20833333 80.20833333]
#  [81.25       81.51041667 81.25       81.51041667 81.51041667 81.25
#   81.51041667 81.51041667 81.51041667 81.51041667]
#  [80.98958333 81.25       81.25       80.98958333 80.72916667 80.72916667
#   80.46875    80.20833333 80.20833333 80.46875   ]
#  [80.46875    79.94791667 80.46875    80.20833333 79.94791667 79.16666667
#   79.42708333 78.125      78.125      77.08333333]
#  [64.0625     52.60416667 47.39583333 42.70833333 39.58333333  0.
# ...

# %% [markdown]
# ## TID SNN

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

def get_allfile(path):  
    all_file = []
    for f in os.listdir(path):  
        f_name = os.path.join(path, f)
        all_file.append(f_name)
    return all_file
    
roots = 'D:/code/EAST/grad/TIDigits_SNN'
file_list = get_allfile(roots)
matrix = np.zeros((10, 10))

for i in range(len(file_list)):
    x = int(float(file_list[i].split('_')[-2]) * 10) - 1
    y = int(float(file_list[i].split('_')[-1]) * 5) - 1
    f = np.loadtxt(os.path.join(file_list[i], 'testacc.txt'))
    matrix[x, y] = f[:,1].max()
print(matrix)
print(matrix[0,0])

print(np.where(matrix==matrix.max()))

plt.imshow(matrix[:,:], cmap='rainbow')
plt.colorbar()
plt.show()
# Out:
# [[12.76041667 12.76041667 12.76041667 12.76041667 12.76041667  9.63541667
#    9.63541667  9.63541667  9.63541667  9.63541667]
#  [12.76041667 12.76041667 12.76041667 12.76041667 12.76041667  9.63541667
#    9.63541667  9.63541667  9.63541667  9.63541667]
#  [24.21875    21.875      24.73958333 36.45833333 39.0625     70.05208333
#    9.63541667  9.63541667  9.63541667  9.63541667]
#  [46.35416667 41.14583333 47.65625    43.75       48.17708333 50.26041667
#   45.05208333 51.82291667 46.61458333 51.04166667]
#  [92.96875    92.70833333 94.27083333 94.27083333 93.75       94.53125
#   94.27083333 94.79166667 95.05208333 94.27083333]
#  [ 9.63541667  9.63541667  9.63541667  9.63541667  9.63541667  9.63541667
#    9.63541667  9.63541667  9.63541667  9.63541667]
#  [ 9.63541667  9.63541667  9.63541667  9.63541667  9.63541667  9.63541667
#    9.63541667  9.63541667  9.63541667  9.63541667]
#  [ 9.63541667  9.63541667  9.63541667  9.63541667  9.63541667  9.63541667
# ...

# %% [markdown]
# ## MNI ANN

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

def get_allfile(path):  
    all_file = []
    for f in os.listdir(path):  
        f_name = os.path.join(path, f)
        all_file.append(f_name)
    return all_file
    
roots = 'D:/code/EAST/grad/MNIST_ANN'
file_list = get_allfile(roots)
matrix = np.zeros((10, 10))

for i in range(len(file_list)):
    x = int(float(file_list[i].split('_')[-2]) * 10) - 1

    y = int(float(file_list[i].split('_')[-1]) * 5) - 1

    f = np.loadtxt(os.path.join(file_list[i], 'testacc.txt'))
    matrix[x, y] = f[:,1].max()
print(matrix.max())
print(matrix)
print(np.where(matrix==matrix.max()))
print(matrix[5,9])
plt.imshow(matrix[:,:], cmap='rainbow')
plt.colorbar()
plt.show()
# Out:
# 87.76041666666667
# [[23.17708333 23.17708333 23.30729167 23.4375     76.04166667 22.78645833
#   22.78645833 22.78645833 22.78645833 22.78645833]
#  [24.34895833 23.95833333 23.17708333 30.20833333 84.765625   63.02083333
#   39.32291667 31.77083333 24.21875    23.95833333]
#  [76.69270833 79.94791667 80.46875    83.33333333 86.45833333 86.84895833
#   84.24479167 83.72395833 83.203125   82.8125    ]
#  [85.41666667 85.41666667 86.328125   86.97916667 87.5        87.36979167
#   87.36979167 87.5        87.36979167 87.23958333]
#  [87.36979167 87.23958333 87.5        87.5        87.63020833 87.5
#   87.76041667 87.76041667 87.63020833 87.63020833]
#  [87.63020833 87.5        87.5        87.23958333 86.97916667 86.84895833
#   86.58854167 86.45833333 86.45833333 86.58854167]
#  [85.67708333 85.67708333 85.41666667 85.02604167 85.02604167 84.765625
#   84.375      83.984375   83.59375    83.07291667]
#  [66.14583333 56.90104167 52.86458333 49.21875    47.52604167 47.13541667
# ...

# %% [markdown]
# ## MNI SNN

# %%
import matplotlib.pyplot as plt
import numpy as np

def get_allfile(path):  
    all_file = []
    for f in os.listdir(path):  
        f_name = os.path.join(path, f)
        all_file.append(f_name)
    return all_file
    
roots = 'D:/code/EAST/grad/MNIST_SNN'
file_list = get_allfile(roots)
matrix = np.zeros((10, 10))

for i in range(len(file_list)):
    x = int(float(file_list[i].split('_')[-2]) * 10) - 1
    y = int(float(file_list[i].split('_')[-1]) * 5) - 1
    f = np.loadtxt(os.path.join(file_list[i], 'testacc.txt'))
    matrix[x, y] = f[:,1].max()
print(matrix)
print(np.where(matrix==matrix.max()))
plt.imshow(matrix[:,:], cmap='rainbow', vmin=30, vmax=matrix.max())
plt.colorbar()
plt.show()
# Out:
# [[27.21354167 26.82291667 26.69270833 26.69270833 36.97916667  8.984375
#    8.984375    8.984375    8.984375    8.984375  ]
#  [24.73958333 25.78125    29.16666667 27.99479167 77.86458333 91.66666667
#   89.32291667 87.63020833 85.28645833 83.59375   ]
#  [80.59895833 81.51041667 82.29166667 83.85416667 85.9375     90.49479167
#   91.66666667 91.53645833 91.40625    90.625     ]
#  [88.93229167 89.0625     89.19270833 89.32291667 89.84375    90.625
#   89.71354167 90.36458333 90.49479167 90.625     ]
#  [91.27604167 90.75520833 90.88541667 91.015625   91.015625   91.015625
#   91.14583333 91.40625    91.14583333 91.27604167]
#  [91.92708333 92.05729167 92.05729167 91.92708333 91.66666667 92.05729167
#   92.1875     92.05729167 91.92708333 91.796875  ]
#  [89.97395833 90.49479167 90.36458333 90.10416667 89.84375    89.453125
#   89.71354167 88.93229167 88.80208333 88.671875  ]
#  [57.29166667 56.11979167 56.77083333 56.90104167 57.16145833 42.70833333
# ...

# %% [markdown]
# # TIDigits

# %% [markdown]
# ## SNN

# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from matplotlib.ticker import FuncFormatter
import xlrd

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

def plot(list_, *args):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    print(args[0], data[:,np.where(data.mean(0)==data.mean(0).max())[0][0]])
    plt.plot(np.arange(data.shape[1])+1, data.mean(0), color=args[1], label=args[0], linewidth=3)
    plt.fill_between(np.arange(data.shape[1])+1, data.mean(0)-data.std(0)*0.5, data.mean(0)+data.std(0)*0.5, color=args[1], alpha=.1)

    print(args[0]+'_max:', data.mean(0).max(), data.std(0)[np.where(data.mean(0)==data.mean(0).max())[0][0]])

def Data(list_):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length)
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    return data.mean(0), data.std(0)


plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16

root = 'D:/code/EAST/data/new'
plot(['2022091516h59m51s_naca_snn_tidigits_0_0.5_1.2_0.1_3/testacc.txt',
     '2022091516h59m51s_naca_snn_tidigits_2_0.5_1.2_0.1_3/testacc.txt',
      '2022091516h59m51s_naca_snn_tidigits_3_0.5_1.2_0.1_3/testacc.txt',
      '2022091516h59m51s_naca_snn_tidigits_4_0.5_1.2_0.1_3/testacc.txt',
      '2022091516h59m51s_naca_snn_tidigits_5_0.5_1.2_0.1_3/testacc.txt',
    ], 'NACA', 'C1')
root = 'D:/code/EAST/data/new'
plot(['2022_09_13_05_23_37_eprop_snn_tidigits_0/2022_09_13_05_23_37_eprop_snn_tidigits_0-0/testacc.txt',
     '2022_09_13_05_27_03_eprop_snn_tidigits_1/2022_09_13_05_27_03_eprop_snn_tidigits_1-1/testacc.txt',
     '2022_09_13_05_27_03_eprop_snn_tidigits_2/2022_09_13_05_27_03_eprop_snn_tidigits_2-2/testacc.txt',
     '2022_09_13_05_27_03_eprop_snn_tidigits_3/2022_09_13_05_27_03_eprop_snn_tidigits_3-3/testacc.txt',
     '2022_09_13_05_27_03_eprop_snn_tidigits_4/2022_09_13_05_27_03_eprop_snn_tidigits_4-4/testacc.txt',], 'Eprop', 'C0')
root = 'D:/code/EAST/data/new'
plot(['2022091310h19m34s_brp_snn_tidigits_0/testacc.txt',
     '2022091310h19m34s_brp_snn_tidigits_2/testacc.txt',
     '2022091310h19m34s_brp_snn_tidigits_3/testacc.txt',
      '2022091317h35m21s_brp_snn_tidigits_7/testacc.txt',
      '2022091317h35m22s_brp_snn_tidigits_6/testacc.txt'], 'BRP', 'C2')
plt.ylim([80,100])
plt.xlim([0, 105])

plt.legend(loc='lower left')
plt.savefig('tidigits_snn.svg')
plt.show()
# Out:
# 100
# NACA [98.78246753 98.21428571 98.86363636 98.53896104 98.37662338]
# NACA_max: 98.55519480519482 0.24296476537493342
# 100
# Eprop [97.07386478 97.48376685 96.01866982 96.98457865 95.65746862]
# Eprop_max: 96.64366974459065 0.6885154133838146
# 100
# BRP [98.37662338 98.05194805 97.6461039  98.45779221 97.6461039 ]
# BRP_max: 98.03571428571429 0.3458973336471185

# %% [markdown]
# ## ANN

# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from matplotlib.ticker import FuncFormatter
import xlrd

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

def plot(list_, *args):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length)
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    print(args[0], data[:,np.where(data.mean(0)==data.mean(0).max())[0][0]])
    plt.plot(np.arange(data.shape[1])+1, data.mean(0), color=args[1], label=args[0], linewidth=3)
    plt.fill_between(np.arange(data.shape[1])+1, data.mean(0)-data.std(0)*0.5, data.mean(0)+data.std(0)*0.5, color=args[1], alpha=.1)
    print(args[0]+'_max:', data.mean(0).max(), data.std(0)[np.where(data.mean(0)==data.mean(0).max())[0][0]])

def Data(list_):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length)
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    return data.mean(0), data.std(0)

# NACA
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16
root = 'D:/code/EAST/data/new'
plot(['2022091217h59m22s_naca_ann_tidigits_0_0.5_1.2/testacc.txt',
     '2022091219h08m38s_naca_ann_tidigits_1_0.5_1.2/testacc.txt',
     '2022091219h08m38s_naca_ann_tidigits_2_0.5_1.2/testacc.txt',
     '2022091219h08m38s_naca_ann_tidigits_3_0.5_1.2/testacc.txt',
     '2022091219h08m38s_naca_ann_tidigits_4_0.5_1.2/testacc.txt'], 'NACA', 'C1')
root = 'D:/code/EAST/data/new'
plot(['2022091218h01m52s_BP_ANN_TIDigits_0_BP/testacc.txt',
     '2022091219h11m51s_BP_ANN_TIDigits_1_BP/testacc.txt',
     '2022091219h11m51s_BP_ANN_TIDigits_2_BP/testacc.txt',
     '2022091219h11m51s_BP_ANN_TIDigits_3_BP/testacc.txt',
     '2022091219h11m51s_BP_ANN_TIDigits_4_BP/testacc.txt'], 'BP', 'C4')
root = 'D:/code/EAST/data/new'
plot(['2022091218h02m33s_TP_ANN_TIDigits_0_DFA/testacc.txt',
     '2022091220h41m41s_TP_ANN_TIDigits_1_DFA/testacc.txt',
     '2022091220h41m41s_TP_ANN_TIDigits_2_DFA/testacc.txt',
     '2022091220h41m41s_TP_ANN_TIDigits_3_DFA/testacc.txt',
     '2022091220h41m41s_TP_ANN_TIDigits_4_DFA/testacc.txt'], 'TP', 'C8')

plt.ylim([80,100])
plt.legend(loc='lower left')
plt.savefig('tidigits_ann.svg')
plt.show()
# Out:
# 100
# NACA [99.43181818 99.51298701 99.35064935 99.43181818 99.10714286]
# NACA_max: 99.36688311688313 0.13964813745198987
# 100
# BP [98.94480519 99.02597403 99.02597403 98.78246753 98.94480519]
# BP_max: 98.94480519480518 0.0889159995949922
# 100
# TP [98.62012987 98.78246753 98.37662338 98.53896104 98.62012987]
# TP_max: 98.58766233766232 0.1318837403350026

# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from matplotlib.ticker import FuncFormatter
import xlrd

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

def plot(list_, *args):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length)
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    plt.plot(np.arange(data.shape[1])+1, data.mean(0), color=args[1], label=args[0], linewidth=3)
    plt.fill_between(np.arange(data.shape[1])+1, data.mean(0)-data.std(0)*0.5, data.mean(0)+data.std(0)*0.5, color=args[1], alpha=.1)
    plt.gca().yaxis.set_major_formatter(FuncFormatter(to_percent))
    print(args[0]+'_max:', data.mean(0).max(), data.std(0)[np.where(data.mean(0)==data.mean(0).max())[0][0]])

def Data(list_):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length)
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    return data.mean(0), data.std(0)

plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16
root = 'D:/Downloads/supplement/supplement'

plot(['2022060910h56m16s_NACA_TIDigits_0/testacc.txt',
     '2022060910h58m04s_NACA_TIDigits_17/testacc.txt',
     '2022060910h58m11s_NACA_TIDigits_34/testacc.txt',
     '2022060910h58m23s_NACA_TIDigits_51/testacc.txt',
     '2022060910h58m32s_NACA_TIDigits_68/testacc.txt'], 'NACA', 'C1')

plot([
    '2022052922h55m53s_Eprop_ANN_TIDigits_0/testacc.txt',
     '2022052922h55m53s_Eprop_ANN_TIDigits_17/testacc.txt',
     '2022052922h55m49s_Eprop_ANN_TIDigits_34/testacc.txt',
     '2022052922h55m55s_Eprop_ANN_TIDigits_68/testacc.txt'
     ], 'Eprop', 'C8')

plot(['2022060216h05m19s_BP_ANN_TIDigits_0/testacc.txt',
     '2022060216h05m19s_BP_ANN_TIDigits_17/testacc.txt',
     '2022060216h05m20s_BP_ANN_TIDigits_34/testacc.txt',
     '2022060216h05m19s_BP_ANN_TIDigits_51/testacc.txt',
     '2022060216h05m19s_BP_ANN_TIDigits_68/testacc.txt'], 'SNU', 'C4')

plt.ylim([60,100])
brp,brpstd = Data(['2022053111h06m34s_BRP_ANN_TIDigits_hdotLB_mean-LB_0/testacc.txt',
     '2022053111h06m33s_BRP_ANN_TIDigits_hdotLB_mean-LB_17/testacc.txt',
     '2022053111h06m34s_BRP_ANN_TIDigits_hdotLB_mean-LB_34/testacc.txt',
     '2022053111h06m34s_BRP_ANN_TIDigits_hdotLB_mean-LB_51/testacc.txt',
           ])
eprop,epropstd = Data(['2022052922h55m53s_Eprop_ANN_TIDigits_0/testacc.txt',
     '2022052922h55m53s_Eprop_ANN_TIDigits_17/testacc.txt',
     '2022052922h55m49s_Eprop_ANN_TIDigits_34/testacc.txt',
     '2022052922h55m49s_Eprop_ANN_TIDigits_51/testacc.txt',
     '2022052922h55m55s_Eprop_ANN_TIDigits_68/testacc.txt'])
bp,bpstd = Data(['2022060216h05m19s_BP_ANN_TIDigits_0/testacc.txt',
     '2022060216h05m19s_BP_ANN_TIDigits_17/testacc.txt',
     '2022060216h05m20s_BP_ANN_TIDigits_34/testacc.txt',
     '2022060216h05m19s_BP_ANN_TIDigits_51/testacc.txt',
     '2022060216h05m19s_BP_ANN_TIDigits_68/testacc.txt'])
print(brp.max(), brpstd[np.where(brp==brp.max())[0][0]], eprop.max(), epropstd[np.where(eprop==eprop.max())[0][0]])
print(bp.max(), bpstd[np.where(bp==bp.max())[0][0]])
plt.legend(loc='lower left')
plt.savefig('tidigits_ann.svg')
plt.show()
# Out:
# 100
# NACA_max: 97.78135048231512 0.29028086953806687
# 100
# Eprop_max: 96.18951612903226 0.46807204702596156
# 100
# SNU_max: 97.40259740259741 0.0
# 100
# 100
# 100
# 96.52549342105263 0.10682879158524759 95.53225806451613 0.20780804397944042
# 97.61290322580645 0.23149516281301932
# 100
# SNN BRP: 95.46774193548387 0.3620958761394154
# 100
# SNU SNN: 98.09677419354838 0.29565004483585733

# %% [markdown]
# # MNIST

# %% [markdown]
# ## SNN

# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from matplotlib.ticker import FuncFormatter
import xlrd

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

def plot(list_, *args):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    print(args[0], data[:,np.where(data.mean(0)==data.mean(0).max())[0][0]])
    plt.plot(np.arange(data.shape[1])+1, data.mean(0), color=args[1], label=args[0], linewidth=3)
    plt.fill_between(np.arange(data.shape[1])+1, data.mean(0)-data.std(0)*0.5, data.mean(0)+data.std(0)*0.5, color=args[1], alpha=.1)
    print(args[0]+'_max:', data.mean(0).max(), data.std(0)[np.where(data.mean(0)==data.mean(0).max())[0][0]])

def Data(list_):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[10])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    return data.mean(0), data.std(0)

plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16
root = 'D:/code/EAST/data/new'
plot([
    '2022091505h05m24s_naca_snn_mnist_0_0.5_1.2_1.0_3/testacc.txt',
     '2022091505h05m24s_naca_snn_mnist_1_0.5_1.2_1.0_3/testacc.txt',
     '2022091505h05m24s_naca_snn_mnist_2_0.5_1.2_1.0_3/testacc.txt',
      '2022091505h05m24s_naca_snn_mnist_3_0.5_1.2_1.0_3/testacc.txt',
      '2022091505h05m24s_naca_snn_mnist_4_0.5_1.2_1.0_3/testacc.txt'
], 'NACA', 'C1')
root = 'D:/code/EAST/data/new'
plot([
    '2022_09_13_05_28_06_eprop_snn_mnist_0/2022_09_13_05_28_06_eprop_snn_mnist_0-0/testacc.txt',
    '2022_09_13_05_31_30_eprop_snn_mnist_1/2022_09_13_05_31_30_eprop_snn_mnist_1-1/testacc.txt',
    '2022_09_13_05_32_27_eprop_snn_mnist_2/2022_09_13_05_32_27_eprop_snn_mnist_2-2/testacc.txt',
    '2022_09_13_21_10_14_eprop_snn_mnist_3/2022_09_13_21_10_14_eprop_snn_mnist_3-3/testacc.txt',
    '2022_09_13_21_10_14_eprop_snn_mnist_4/2022_09_13_21_10_14_eprop_snn_mnist_4-4/testacc.txt'], 'E-prop', 'C0')
root = 'D:/code/EAST/data/new'
plot([
    '2022092104h53m14s_brp_snn_mnist_0/testacc.txt',
    '2022092104h53m15s_brp_snn_mnist_1/testacc.txt',
    '2023052011h37m46s_mnist_brp_3/testacc.txt',
    '2023052011h38m58s_mnist_brp_4/testacc.txt',
    '2023052011h39m09s_mnist_brp_5/testacc.txt'
    ], 'BRP', 'C2')

plt.ylim([90,100])

plt.legend(loc='lower left')
plt.savefig('mnist_snn.svg')
plt.show()
# Out:
# 100
# NACA [99.04847756 99.05849359 98.92828526 99.10857372 99.00841346]
# NACA_max: 99.03044871794872 0.06022955279796566
# 100
# E-prop [98.03034934 98.42297756 98.02884704 98.22816585 98.16506499]
# E-prop_max: 98.17508095732101 0.14608398137406392
# 100
# BRP [98.61778846 98.88822115 98.70793269 98.46754808 98.77804487]
# BRP_max: 98.69190705128206 0.14286097219291283

# %% [markdown]
# ## ANN

# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from matplotlib.ticker import FuncFormatter
import xlrd

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

def plot(list_, *args):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length)
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    print(data.shape)
    print(args[0], data[:,np.where(data.mean(0)==data.mean(0).max())[0][0]])
    plt.plot(np.arange(data.shape[1])+1, data.mean(0), color=args[1], label=args[0], linewidth=3)
    plt.fill_between(np.arange(data.shape[1])+1, data.mean(0)-data.std(0)*0.5, data.mean(0)+data.std(0)*0.5, color=args[1], alpha=.1)
    print(args[0]+'_max:', data.mean(0).max(), data.std(0)[np.where(data.mean(0)==data.mean(0).max())[0][0]])

def Data(list_):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length)
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    return data.mean(0), data.std(0)

plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16
root = 'D:/code/EAST/data/new'
plot(['2022090709h08m47s_NACA_ANN_MNIST_0/testacc.txt',
     '2022090709h08m46s_NACA_ANN_MNIST_17/testacc.txt',
     '2022090709h08m47s_NACA_ANN_MNIST_34/testacc.txt',
     '2022090709h08m47s_NACA_ANN_MNIST_51/testacc.txt',
     '2022090709h08m46s_NACA_ANN_MNIST_68/testacc.txt'], 'NACA', 'C1')
root = 'D:/code/EAST/data/new'
plot(['2022091217h46m52s_TP_ANN_MNIST_0_DFA/testacc.txt',
      '2022091221h01m58s_TP_ANN_MNIST_1_DFA/testacc.txt',
      '2022091221h01m58s_TP_ANN_MNIST_2_DFA/testacc.txt',
      '2022091221h01m58s_TP_ANN_MNIST_3_DFA/testacc.txt',
      '2022091221h01m58s_TP_ANN_MNIST_4_DFA/testacc.txt',
     ], 'TP', 'C8')
root = 'D:/code/EAST/data/new'
plot(['2022091217h46m04s_BP_ANN_MNIST_0_BP/testacc.txt',
      '2022091220h40m06s_BP_ANN_MNIST_1_BP/testacc.txt',
      '2022091220h40m06s_BP_ANN_MNIST_2_BP/testacc.txt',
      '2022091220h40m06s_BP_ANN_MNIST_3_BP/testacc.txt',
      '2022091220h40m06s_BP_ANN_MNIST_4_BP/testacc.txt',
     ], 'BP', 'C4')
plt.ylim([90,100])

plt.legend(loc='lower left')
plt.savefig('mnist_ann.svg')
plt.show()
# Out:
# 100
# (5, 100)
# NACA [99.39903846 99.31891026 99.40905449 99.39903846 99.30889423]
# NACA_max: 99.36698717948718 0.04361286269446739
# 100
# (5, 100)
# TP [98.89823718 99.02844551 98.81810897 99.10857372 98.90825321]
# TP_max: 98.9523237179487 0.10304343869880934
# 100
# (5, 100)
# BP [99.22876603 99.2588141  99.14863782 99.26883013 99.1786859 ]
# BP_max: 99.2167467948718 0.04629094554603868

# %% [markdown]
# # Computational cost

# %% [markdown]
# ## TID & MNI in NACA,Eprop,BRP,TP,BP

# %%
def Data(list_,list_1,list_2, min_margin,*arg):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data1 = np.array(data)
    
    length = []
    data = []
    for i in range(len(list_1)):
        file = np.loadtxt(os.path.join(root, list_1[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data2 = np.array(data)
    
    length = []
    data = []
    for i in range(len(list_2)):
        file = np.loadtxt(os.path.join(root, list_2[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data3 = np.array(data)
    
    Err1 = (100-data1).mean(0)
    Err2 = (100-data2).mean(0)
    Err3 = (100-data3).mean(0)
    
    data1 = 100 - data1
    data2 = 100 - data2
    data3 = 100 - data3
    
    max_ = 100 - min_margin
    min_ = max(Err1.min(), Err2.min(), Err3.min())
    
#     print('Data:', max_, min_)
    
    # 1
    errlist = np.linspace(min_, max_, 5)
#     print(errlist)
    epoch = data1.shape[0]
    err = np.zeros((len(errlist)))
    Err = []
    for i in range(len(list_)):
        for j in range(len(errlist)):
            try:
                err[j] = np.where(data1[i] >= errlist[j])[0][-1]
            except:
                err[j] = 0
        mean_, std_ = err.mean(), err.std()/np.sqrt(5)
        Err.append(mean_)
    print(arg[0]+':', np.array(Err).mean(), np.array(Err).std())
    print(Err)
    # 2
    errlist = np.linspace(min_, max_, 5)
    epoch = data2.shape[0]
    err = np.zeros((len(errlist)))
    Err = []
    for i in range(len(list_)):
        for j in range(len(errlist)):
            try:
                err[j] = np.where(data2[i] >= errlist[j])[0][-1]
            except:
                err[j] = 0
        mean_, std_ = err.mean(), err.std()/np.sqrt(5)
        Err.append(mean_)
    print(arg[1]+':', np.array(Err).mean(), np.array(Err).std())
    print(Err)
    # 3
    errlist = np.linspace(min_, max_, 5)
    epoch = data3.shape[0]
    err = np.zeros((len(errlist)))
    Err = []
    for i in range(len(list_)):
        for j in range(len(errlist)):
            try:
                err[j] = np.where(data3[i] >= errlist[j])[0][-1]
            except:
                err[j] = 0
        mean_, std_ = err.mean(), err.std()/np.sqrt(5)
        Err.append(mean_)
    print(arg[2]+':', np.array(Err).mean(), np.array(Err).std())
    print(Err)
    return 

# SNN TID 
root = 'D:/code/EAST/data/new'
_ = Data(['2022091516h59m51s_naca_snn_tidigits_0_0.5_1.2_0.1_3/testacc.txt',
     '2022091516h59m51s_naca_snn_tidigits_2_0.5_1.2_0.1_3/testacc.txt',
      '2022091516h59m51s_naca_snn_tidigits_3_0.5_1.2_0.1_3/testacc.txt',
      '2022091516h59m51s_naca_snn_tidigits_4_0.5_1.2_0.1_3/testacc.txt',
      '2022091516h59m51s_naca_snn_tidigits_5_0.5_1.2_0.1_3/testacc.txt',
    ],
    ['2022_09_13_05_23_37_eprop_snn_tidigits_0/2022_09_13_05_23_37_eprop_snn_tidigits_0-0/testacc.txt',
     '2022_09_13_05_27_03_eprop_snn_tidigits_1/2022_09_13_05_27_03_eprop_snn_tidigits_1-1/testacc.txt',
     '2022_09_13_05_27_03_eprop_snn_tidigits_2/2022_09_13_05_27_03_eprop_snn_tidigits_2-2/testacc.txt',
     '2022_09_13_05_27_03_eprop_snn_tidigits_3/2022_09_13_05_27_03_eprop_snn_tidigits_3-3/testacc.txt',
     '2022_09_13_05_27_03_eprop_snn_tidigits_4/2022_09_13_05_27_03_eprop_snn_tidigits_4-4/testacc.txt',],
    ['2022091310h19m34s_brp_snn_tidigits_0/testacc.txt',
     '2022091310h19m34s_brp_snn_tidigits_2/testacc.txt',
     '2022091310h19m34s_brp_snn_tidigits_3/testacc.txt',
      '2022091317h35m21s_brp_snn_tidigits_7/testacc.txt',
      '2022091317h35m22s_brp_snn_tidigits_6/testacc.txt'], 90,'***SNN_TIDigits_NACA','***SNN_TIDigits_Eprop','***SNN_TIDigits_BRP')

# SNN MNIST 
root = 'D:/code/EAST/data/new'
_ = Data([
    '2022091505h05m24s_naca_snn_mnist_0_0.5_1.2_1.0_3/testacc.txt',
     '2022091505h05m24s_naca_snn_mnist_1_0.5_1.2_1.0_3/testacc.txt',
     '2022091505h05m24s_naca_snn_mnist_2_0.5_1.2_1.0_3/testacc.txt',
      '2022091505h05m24s_naca_snn_mnist_3_0.5_1.2_1.0_3/testacc.txt',
      '2022091505h05m24s_naca_snn_mnist_4_0.5_1.2_1.0_3/testacc.txt'
],
    [
    '2022_09_13_05_28_06_eprop_snn_mnist_0/2022_09_13_05_28_06_eprop_snn_mnist_0-0/testacc.txt',
    '2022_09_13_05_31_30_eprop_snn_mnist_1/2022_09_13_05_31_30_eprop_snn_mnist_1-1/testacc.txt',
    '2022_09_13_05_32_27_eprop_snn_mnist_2/2022_09_13_05_32_27_eprop_snn_mnist_2-2/testacc.txt',
    '2022_09_13_21_10_14_eprop_snn_mnist_3/2022_09_13_21_10_14_eprop_snn_mnist_3-3/testacc.txt',
    '2022_09_13_21_10_14_eprop_snn_mnist_4/2022_09_13_21_10_14_eprop_snn_mnist_4-4/testacc.txt'],
    [
    '2022092104h53m14s_brp_snn_mnist_0/testacc.txt',
    '2022092104h53m15s_brp_snn_mnist_1/testacc.txt',
    '2023052011h37m46s_mnist_brp_3/testacc.txt',
    '2023052011h38m58s_mnist_brp_4/testacc.txt',
    '2023052011h39m09s_mnist_brp_5/testacc.txt'
    ], 95,'***SNN_MNIST_NACA','***SNN_MNIST_Eprop','***SNN_MNIST_BRP')

# ANN MNIST 
root = 'D:/code/EAST/data/new'
_ = Data(['2022090709h08m47s_NACA_ANN_MNIST_0/testacc.txt',
     '2022090709h08m46s_NACA_ANN_MNIST_17/testacc.txt',
     '2022090709h08m47s_NACA_ANN_MNIST_34/testacc.txt',
     '2022090709h08m47s_NACA_ANN_MNIST_51/testacc.txt',
     '2022090709h08m46s_NACA_ANN_MNIST_68/testacc.txt'],
    ['2022091217h46m52s_TP_ANN_MNIST_0_DFA/testacc.txt',
      '2022091221h01m58s_TP_ANN_MNIST_1_DFA/testacc.txt',
      '2022091221h01m58s_TP_ANN_MNIST_2_DFA/testacc.txt',
      '2022091221h01m58s_TP_ANN_MNIST_3_DFA/testacc.txt',
      '2022091221h01m58s_TP_ANN_MNIST_4_DFA/testacc.txt',
     ],
    ['2022091217h46m04s_BP_ANN_MNIST_0_BP/testacc.txt',
      '2022091220h40m06s_BP_ANN_MNIST_1_BP/testacc.txt',
      '2022091220h40m06s_BP_ANN_MNIST_2_BP/testacc.txt',
      '2022091220h40m06s_BP_ANN_MNIST_3_BP/testacc.txt',
      '2022091220h40m06s_BP_ANN_MNIST_4_BP/testacc.txt',
     ],95, '***ANN_MNIST_NACA','***ANN_MNIST_TP','***ANN_MNIST_BP')

# ANN TID
root = 'D:/code/EAST/data/new'
_ = Data(['2022091217h59m22s_naca_ann_tidigits_0_0.5_1.2/testacc.txt',
     '2022091219h08m38s_naca_ann_tidigits_1_0.5_1.2/testacc.txt',
     '2022091219h08m38s_naca_ann_tidigits_2_0.5_1.2/testacc.txt',
     '2022091219h08m38s_naca_ann_tidigits_3_0.5_1.2/testacc.txt',
     '2022091219h08m38s_naca_ann_tidigits_4_0.5_1.2/testacc.txt'],
    ['2022091218h02m33s_TP_ANN_TIDigits_0_DFA/testacc.txt',
     '2022091220h41m41s_TP_ANN_TIDigits_1_DFA/testacc.txt',
     '2022091220h41m41s_TP_ANN_TIDigits_2_DFA/testacc.txt',
     '2022091220h41m41s_TP_ANN_TIDigits_3_DFA/testacc.txt',
     '2022091220h41m41s_TP_ANN_TIDigits_4_DFA/testacc.txt'],
    ['2022091218h01m52s_BP_ANN_TIDigits_0_BP/testacc.txt',
     '2022091219h11m51s_BP_ANN_TIDigits_1_BP/testacc.txt',
     '2022091219h11m51s_BP_ANN_TIDigits_2_BP/testacc.txt',
     '2022091219h11m51s_BP_ANN_TIDigits_3_BP/testacc.txt',
     '2022091219h11m51s_BP_ANN_TIDigits_4_BP/testacc.txt'], 90,'***ANN_TID_NACA','***ANN_TID_TP','***ANN_TID_BP')
# Out:
# 100
# 100
# 100
# ***SNN_TIDigits_NACA: 14.64 7.70184393505867
# [9.6, 26.0, 21.8, 7.8, 8.0]
# ***SNN_TIDigits_Eprop: 74.84 12.241176414054326
# [68.6, 57.2, 83.6, 92.6, 72.2]
# ***SNN_TIDigits_BRP: 24.759999999999998 6.2806369103778
# [14.2, 24.8, 29.0, 23.0, 32.8]
# 100
# 100
# 100
# ***SNN_MNIST_NACA: 2.6799999999999997 0.78587530817554
# [1.8, 2.8, 3.8, 3.2, 1.8]
# ***SNN_MNIST_Eprop: 48.96 2.79256154811313
# [49.4, 50.4, 47.2, 53.0, 44.8]
# ***SNN_MNIST_BRP: 20.959999999999997 6.5695053086210375
# [25.4, 14.2, 12.8, 30.0, 22.4]
# 100
# 100
# 100
# ***ANN_MNIST_NACA: 2.88 0.15999999999999998
# [3.0, 2.8, 3.0, 2.6, 3.0]
# ***ANN_MNIST_TP: 25.72 6.166490087561967
# [38.0, 22.6, 23.6, 21.8, 22.6]
# ***ANN_MNIST_BP: 5.5600000000000005 2.9268413007882743
# [7.0, 2.4, 9.2, 1.8, 7.4]
# 100
# 100
# 100
# ***ANN_TID_NACA: 19.52 1.9497692171126297
# [18.8, 18.6, 18.6, 18.2, 23.4]
# ***ANN_TID_TP: 33.8 3.853310265213534
# [32.8, 32.0, 41.4, 32.0, 30.8]
# ...

# %% [markdown]
# ### MNI SNN

# %%
import numpy as np

snnmnist = np.array([[2.68, 48.96, 20.96],
            [0.79, 2.79, 6.57]])
snnmnist[1] = snnmnist[1]/np.sqrt(5)

m, n, k = 784, 1000, 10

snncost = np.array([max(m*n, k*m) + max(n*k, k*n),
            m*n+n*n+n*k+k*n+n*n+k*m,
            m*n+n*k+k*n+k*m,
            ])

fig, ax1 = plt.subplots()
x = np.array([[99.03,98.18,98.79],
              [0.06,0.15,0.12]])
print(x)
error_kw = {'capsize': 7, 'ecolor': 'black'}
ax1.bar([0-0.2, 0, 0+0.2], x[0,:],yerr=x[1,:], xerr=0, width=0.2, color=['C1','C0','C2'], error_kw=error_kw)
ax1.set_ylim([90, 100])
plt.xticks(np.arange(2),['ACC','Cost'])
plt.xticks(fontsize=16)
def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

ax2 = ax1.twinx()
x = snnmnist * snncost
print(x)
error_kw = {'capsize': 7, 'ecolor': 'black'}
ax2.bar([1-0.2, 1, 1+0.2], x[0,:],yerr=x[1,:], xerr=0, width=0.2, color=['C1','C0','C2'], error_kw=error_kw)
ax2.set_ylim([0,1.5*1e8])
plt.yticks([0, 1*1e8, 2*1e8], fontsize=16)

plt.savefig('mnist_分类正确率能耗_snn.svg')
plt.show()
# Out:
# [[9.903e+01 9.818e+01 9.879e+01]
#  [6.000e-02 1.500e-01 1.200e-01]]
# [[2.12792000e+06 1.37667686e+08 1.70161664e+07]
#  [2.80519200e+05 3.50840568e+06 2.38534287e+06]]

# %%
import numpy as np
import seaborn as sns

m, n, k = 784, 1000, 10

snncost = np.array([max(m*n, k*m) + max(n*k, k*n),
            m*n+n*n+n*k+k*n+n*n+k*m,
            m*n+n*k+k*n+k*m,
            ])

fig, ax1 = plt.subplots(figsize=(2.5,4))
li_1 = [99.04847756,99.05849359,98.92828526,99.10857372,99.00841346]
li_2 = [98.03034934,98.42297756,98.02884704,98.22816585,98.16506499]
li_3 = [98.61778846,98.88822115,98.70793269,98.46754808,98.77804487]
cmap = {0:sns.color_palette("tab10")[1],1:sns.color_palette("tab10")[0],2:sns.color_palette("tab10")[2]} 
sns.violinplot(data = [li_1, li_2, li_3],palette=cmap,inner="stick", scale="width")
ax1.set_ylim([97, 100])
plt.yticks([97,98,99,100])
plt.xticks(fontsize=16)
plt.savefig('mnist_分类正确率能耗_snn_1.svg')
plt.show()

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

fig, ax1 = plt.subplots(figsize=(2.5,4))
ax1.yaxis.tick_right()
li_1 = np.array([1.8, 2.8, 3.8, 3.2, 1.8]) * snncost[0]
li_2 = np.array([49.4, 50.4, 47.2, 53.0, 44.8]) * snncost[1]
li_3 = np.array([25.4, 14.2, 12.8, 30.0, 22.4]) * snncost[2]
cmap = {0:sns.color_palette("tab10")[1],1:sns.color_palette("tab10")[0],2:sns.color_palette("tab10")[2]} 
sns.violinplot(data = [li_1, li_2, li_3],palette=cmap,inner="stick", scale="width")
plt.yticks([0,1e8,2e8])

print('naca')

plt.savefig('mnist_分类正确率能耗_snn_2.svg')
plt.show()
# Out:
# naca

# %% [markdown]
# ### MNI ANN

# %%
import numpy as np
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from matplotlib.ticker import FuncFormatter
import xlrd
import seaborn as sns

annmnist = np.array([[2.88, 25.72, 5.56],
            [0.16, 6.17, 2.93]])
annmnist[1] = annmnist[1]/np.sqrt(5)

m, n, k = 784, 1000, 10

anncost = np.array([max(m*n, k*m) + max(n*k, k*n),
            m*n+n*k+k*n+k*m,
            m*n+n*n+k*n+n*m])

# cut=0

fig, ax1 = plt.subplots(figsize=(2.5,4))
li_1 = [99.39903846,99.31891026,99.40905449,99.39903846,99.30889423]
li_2 = [98.89823718,99.02844551,98.81810897,99.10857372,98.90825321]
li_3 = [99.22876603,99.2588141, 99.14863782,99.26883013,99.1786859 ]
cmap = {0:sns.color_palette("tab10")[1],1:sns.color_palette("tab10")[0],2:sns.color_palette("tab10")[2]} 
sns.violinplot(data = [li_1, li_2, li_3],palette=cmap, inner="stick", scale="width")
ax1.set_ylim([97, 100])
plt.yticks([97,98,99,100])
plt.xticks(fontsize=16)
plt.savefig('mnist_分类正确率能耗_ann_1.svg')
plt.show()
def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

fig, ax1 = plt.subplots(figsize=(2.5,4))
ax1.yaxis.tick_right()
li_1 = np.array([3.0, 2.8, 3.0, 2.6, 3.0]) * anncost[0]
li_2 = np.array([38.0, 22.6, 23.6, 21.8, 22.6]) * anncost[1] 
li_3 = np.array([7.0, 2.4, 9.2, 1.8, 7.4]) * anncost[2]
print(li_3)
cmap = {0:sns.color_palette("tab10")[1],1:sns.color_palette("tab10")[0],2:sns.color_palette("tab10")[2]} 
sns.violinplot(data = [li_1, li_2, li_3],palette=cmap,inner="stick", scale="width")
# inner, “box”, “quartile”, “point”, “stick”,
# scale,“area”, “count”, “width”
# bw{‘scott’, ‘silverman’, float}, optional
plt.yticks([0,1e8])

plt.savefig('mnist_分类正确率能耗_ann_2.svg')
plt.show()
# Out:
# [18046000.  6187200. 23717600.  4640400. 19077200.]

# %%
li_1 = [1,2,3,4,5]
li_2 = [1,2,3,4,5]
li_3 = [1,2,3,4,5]
sns.violinplot(data = [li_1, li_2, li_3],palette=cmap,cut=2)
plt.show()

# %%
import numpy as np
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from matplotlib.ticker import FuncFormatter
import xlrd

annmnist = np.array([[2.88, 25.72, 5.56],
            [0.16, 6.17, 2.93]])
annmnist[1] = annmnist[1]/np.sqrt(5)

m, n, k = 784, 1000, 10

anncost = np.array([max(m*n, k*m) + max(n*k, k*n),
            m*n+n*k+k*n+k*m,
            m*n+n*n+k*n+n*m])

fig, ax1 = plt.subplots()
x = np.array([[99.37,98.95,99.22],
              [0.04,0.10,0.05]])
print(x)
error_kw = {'capsize': 7, 'ecolor': 'black'}
ax1.bar([0-0.2, 0, 0+0.2], x[0,:],yerr=x[1,:], xerr=0, width=0.2, color=['C1','#bcbd23','#9367bc'], error_kw=error_kw)
ax1.set_ylim([90, 100])
plt.xticks(np.arange(2),['ACC','Cost'])
plt.xticks(fontsize=16)
def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

ax2 = ax1.twinx()
x = annmnist * anncost
print(x)
error_kw = {'capsize': 7, 'ecolor': 'black'}
ax2.bar([1-0.2, 1, 1+0.2], x[0,:],yerr=x[1,:], xerr=0, width=0.2, color=['C1','#bcbd23','#9367bc'], error_kw=error_kw)
ax2.set_ylim([0,3*1e7])
plt.yticks([0, 1*1e7, 2*1e7], fontsize=16)

plt.savefig('mnist_分类正确率能耗_ann.svg')
plt.show()
# Out:
# [[9.937e+01 9.895e+01 9.922e+01]
#  [4.000e-02 1.000e-01 5.000e-02]]
# [[ 2286720.         20880524.8        14333680.        ]
#  [   56814.01517231  2240116.51273713  3378045.78215275]]

# %% [markdown]
# ### TID SNN

# %%
import numpy as np

snntid = np.array([[14.64, 74.84, 24.76],
            [7.70, 12.24, 6.28]])
snntid[1] = snntid[1]/np.sqrt(5)

m, n, k = 900, 1000, 10

print(anncost)
snncost = np.array([max(m*n, k*m) + max(n*k, k*n),
            m*n+n*n+n*k+k*n+n*n+k*m,
            m*n+n*k+k*n+k*m,
            ])

fig, ax1 = plt.subplots(figsize=(2.5,4))
li_1 = [98.78246753,98.21428571,98.86363636,98.53896104,98.37662338]
li_2 = [97.07386478,97.48376685,96.01866982,96.98457865,95.65746862]
li_3 = [98.37662338,98.05194805,97.6461039 , 98.45779221,97.6461039 ]
cmap = {0:sns.color_palette("tab10")[1],1:sns.color_palette("tab10")[0],2:sns.color_palette("tab10")[2]} 
sns.violinplot(data = [li_1, li_2, li_3],palette=cmap,inner="stick", scale="width")
ax1.set_ylim([94, 100])
plt.yticks([94,96,98,100])
plt.xticks(fontsize=16)
plt.savefig('tidigits_分类正确率能耗_snn_1.svg')
plt.show()
def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

fig, ax1 = plt.subplots(figsize=(2.5,4))
ax1.yaxis.tick_right()
li_1 = np.array([9.6, 26.0, 21.8, 7.8, 8.0]) * snncost[0]
li_2 = np.array([68.6, 57.2, 83.6, 92.6, 72.2]) * snncost[1]
li_3 = np.array([14.2, 24.8, 29.0, 23.0, 32.8]) * snncost[2]
cmap = {0:sns.color_palette("tab10")[1],1:sns.color_palette("tab10")[0],2:sns.color_palette("tab10")[2]} 
sns.violinplot(data = [li_1, li_2, li_3],palette=cmap,inner="stick", scale="width")
plt.yticks([0,1e8,2e8,3e8,4e8])

plt.savefig('tidigits_分类正确率能耗_snn_2.svg')
plt.show()
# Out:
# [ 794000  811840 2578000]

# %%
import numpy as np

snntid = np.array([[14.64, 74.84, 24.76],
            [7.70, 12.24, 6.28]])
snntid[1] = snntid[1]/np.sqrt(5)

m, n, k = 900, 1000, 10

print(anncost)
snncost = np.array([max(m*n, k*m) + max(n*k, k*n),
            m*n+n*n+n*k+k*n+n*n+k*m,
            m*n+n*k+k*n+k*m,
            ])

fig, ax1 = plt.subplots()
x = np.array([[98.56,96.64,98.04],
              [0.24,0.69,0.35]])
print(x)
error_kw = {'capsize': 7, 'ecolor': 'black'}
ax1.bar([0-0.2, 0, 0+0.2], x[0,:],yerr=x[1,:], xerr=0, width=0.2, color=['C1','C0','C2'], error_kw=error_kw)
ax1.set_ylim([80, 100])
plt.xticks(np.arange(2),['ACC','Cost'])
plt.xticks(fontsize=16)
def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

ax2 = ax1.twinx()
x = snntid * snncost
print(x)
error_kw = {'capsize': 7, 'ecolor': 'black'}
ax2.bar([1-0.2, 1, 1+0.2], x[0,:],yerr=x[1,:], xerr=0, width=0.2, color=['C1','C0','C2'], error_kw=error_kw)
ax2.set_ylim([0,3*1e8])
plt.yticks([0, 1*1e8, 2*1e8], fontsize=16)

plt.savefig('tidigits_分类正确率能耗_snn.svg')
plt.show()

# %% [markdown]
# ### TID ANN

# %%
import numpy as np

anntid = np.array([[19.52, 33.8,22.2],
            [1.95, 3.85,1.84]])
anntid[1] = anntid[1]/np.sqrt(5)

m, n, k = 900, 1000, 10

anncost = np.array([max(m*n, k*m) + max(n*k, k*n),
            m*n+n*k+k*n+k*m,
            m*n+n*n+k*n+n*m])

print(anncost)

fig, ax1 = plt.subplots(figsize=(2.5,4))
li_1 = [99.43181818,99.51298701,99.35064935,99.43181818,99.10714286]
li_2 = [98.94480519,99.02597403,99.02597403,98.78246753,98.94480519]
li_3 = [98.62012987,98.78246753,98.37662338,98.53896104,98.62012987]
cmap = {0:sns.color_palette("tab10")[1],1:sns.color_palette("tab10")[0],2:sns.color_palette("tab10")[2]} 
sns.violinplot(data = [li_1, li_2, li_3],palette=cmap,inner="stick", scale="width")
ax1.set_ylim([94, 100])
plt.yticks([94,96,98,100])
plt.xticks(fontsize=16)
plt.savefig('tidigits_分类正确率能耗_ann_1.svg')
plt.show()
def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

fig, ax1 = plt.subplots(figsize=(2.5,4))
ax1.yaxis.tick_right()
li_1 = np.array([18.8, 18.6, 18.6, 18.2, 23.4]) * anncost[0]
li_2 = np.array([32.8, 32.0, 41.4, 32.0, 30.8]) * anncost[1]
li_3 = np.array([22.2, 20.4, 23.0, 25.2, 20.2]) * anncost[2]
cmap = {0:sns.color_palette("tab10")[1],1:sns.color_palette("tab10")[0],2:sns.color_palette("tab10")[2]} 
sns.violinplot(data = [li_1, li_2, li_3],palette=cmap,inner="stick", scale="width")
plt.yticks([0,3e7,6e7])

plt.savefig('tidigits_分类正确率能耗_ann_2.svg')
plt.show()
# Out:
# [ 910000  929000 2810000]

# %%
import numpy as np

anntid = np.array([[19.52, 33.8,22.2],
            [1.95, 3.85,1.84]])
anntid[1] = anntid[1]/np.sqrt(5)

m, n, k = 900, 1000, 10

anncost = np.array([max(m*n, k*m) + max(n*k, k*n),
            m*n+n*k+k*n+k*m,
            m*n+n*n+k*n+n*m])

print(anncost)

fig, ax1 = plt.subplots()
x = np.array([[99.37,98.94,98.59],
              [0.14,0.09,0.13]])
print(x)
error_kw = {'capsize': 7, 'ecolor': 'black'}
ax1.bar([0-0.2, 0, 0+0.2], x[0,:],yerr=x[1,:], xerr=0, width=0.2, color=['C1','#bcbd23','#9367bc'], error_kw=error_kw)
ax1.set_ylim([80, 100])
plt.xticks(np.arange(2),['ACC','Cost'])
plt.xticks(fontsize=16)
def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

ax2 = ax1.twinx()
x = anntid * anncost
print(x)
error_kw = {'capsize': 7, 'ecolor': 'black'}
ax2.bar([1-0.2, 1, 1+0.2], x[0,:],yerr=x[1,:], xerr=0, width=0.2, color=['C1','#bcbd23','#9367bc'], error_kw=error_kw)
ax2.set_ylim([0,7*1e7])
plt.yticks([0, 3*1e7,6*1e7], fontsize=16)

plt.savefig('tidigits_分类正确率能耗_ann.svg')
plt.show()

# %% [markdown]
# # Multi layer

# %% [markdown]
# ## TID

# %% [markdown]
# ### SNN

# %%
import numpy as np
import os
def Data(list_, *arg):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    Err = 100-data
    min_ = Err.min(1).max()
    max_ = Err.max(1).min()
    errlist = np.linspace(min_, max_, 5)
    epoch = data.shape[0]

    err = np.zeros((Err.shape[0], len(errlist)))
    for i in range(Err.shape[0]):
        for j in range(len(errlist)):
            err[i, j] = np.where(Err[i] >= errlist[j])[0][-1]
    mean_, std_ = err.mean(1).mean(), err.mean(1).std()/np.sqrt(5)
    return data.mean(0), data.std(0)

root = 'D:\\code\\EAST\\data\\new'
a, b = Data(['2022091820h03m04s_naca_snn_tidigits_layers_3_0_0.5_1.2_0.1_3/testacc.txt',
             '2022091820h03m04s_naca_snn_tidigits_layers_3_1_0.5_1.2_0.1_3/testacc.txt'])
print('NACA TID 3layers:', a.max(), b[np.where(a==a.max())[0][0]])
a, b = Data(['2022092103h53m45s_naca_snn_tidigits_layers_4_1000_0_0.5_1.2_0.1_3/testacc.txt',
             '2022092103h53m45s_naca_snn_tidigits_layers_4_1000_1_0.5_1.2_0.1_3/testacc.txt'])
print('NACA TID 4layers:', a.max(), b[np.where(a==a.max())[0][0]])
a, b = Data(['2022092103h54m47s_naca_snn_tidigits_layers_5_1000_0_0.5_1.2_0.1_3/testacc.txt',
             '2022092103h54m47s_naca_snn_tidigits_layers_5_1000_1_0.5_1.2_0.1_3/testacc.txt'])
print('NACA TID 5layers:', a.max(), b[np.where(a==a.max())[0][0]])
# Out:
# 100
# NACA TID 3layers: 96.83441558441558 0.1623376623376629
# 100
# NACA TID 4layers: 96.38798701298701 0.20292207792208217
# 100
# NACA TID 5layers: 96.14448051948051 0.2840909090909136

# %% [markdown]
# ### ANN

# %%
import numpy as np
import os
def Data(list_, *arg):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    Err = 100-data
    min_ = Err.min(1).max()
    max_ = Err.max(1).min()
    errlist = np.linspace(min_, max_, 5)
    epoch = data.shape[0]
    
    err = np.zeros((Err.shape[0], len(errlist)))
    for i in range(Err.shape[0]):
        for j in range(len(errlist)):
            err[i, j] = np.where(Err[i] >= errlist[j])[0][-1]
    mean_, std_ = err.mean(1).mean(), err.mean(1).std()/np.sqrt(5)
    return data.mean(0), data.std(0)

root = 'D:\\code\\EAST\\data\\new\\multilayers\\1000'
a, b = Data(['2022091722h18m06s_naca_ann_tidigits_3_0_0.5_1.2/testacc.txt',
     '2022091722h18m06s_naca_ann_tidigits_3_1_0.5_1.2/testacc.txt'])
print('NACA TID 3layers:', a.max(), b[np.where(a==a.max())[0][0]])
a, b = Data(['2022092010h02m56s_naca_ann_tidigits_layers_4_1000_2_0.5_1.2/testacc.txt',
             '2022092010h02m56s_naca_ann_tidigits_layers_4_1000_3_0.5_1.2/testacc.txt'])
print('NACA TID 4layers:', a.max(), b[np.where(a==a.max())[0][0]])
a, b = Data(['2022092010h03m02s_naca_ann_tidigits_layers_5_1000_2_0.5_1.2/testacc.txt',
             '2022092010h03m02s_naca_ann_tidigits_layers_5_1000_3_0.5_1.2/testacc.txt'])
print('NACA TID 5layers:', a.max(), b[np.where(a==a.max())[0][0]])
# Out:
# 100
# NACA TID 3layers: 91.72077922077922 0.08116883116882434
# 100
# NACA TID 4layers: 92.00487012987013 0.040584415584419276
# 100
# NACA TID 5layers: 91.9237012987013 0.20292207792207506

# %% [markdown]
# ## MNIST

# %% [markdown]
# ### SNN

# %%
import numpy as np
import os
def Data(list_, *arg):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length)
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    Err = 100-data
    min_ = Err.min(1).max()
    max_ = Err.max(1).min()
    errlist = np.linspace(min_, max_, 5)
    epoch = data.shape[0]

    err = np.zeros((Err.shape[0], len(errlist)))
    for i in range(Err.shape[0]):
        for j in range(len(errlist)):
            err[i, j] = np.where(Err[i] >= errlist[j])[0][-1]
    mean_, std_ = err.mean(1).mean(), err.mean(1).std()/np.sqrt(5)
    return data.mean(0), data.std(0)

root = 'D:/code/EAST/data/new'
a, b = Data(['2022091820h01m39s_naca_snn_mnist_layers_3_0_0.5_1.2_1.0_3/testacc.txt',
         '2022091820h01m39s_naca_snn_mnist_layers_3_1_0.5_1.2_1.0_3/testacc.txt'])
print('NACA mnist 3layers:', a.max(), b[np.where(a==a.max())[0][0]])

a, b = Data(['2022092103h54m00s_naca_snn_mnist_layers_4_1000_0_0.5_1.2_1.0_3/testacc.txt',
             '2022092103h54m00s_naca_snn_mnist_layers_4_1000_1_0.5_1.2_1.0_3/testacc.txt'])
print('NACA mnist 4layers:', a.max(), b[np.where(a==a.max())[0][0]])
a, b = Data(['2022092103h54m30s_naca_snn_mnist_layers_5_1000_0_0.5_1.2_1.0_3/testacc.txt',
             '2022092103h54m30s_naca_snn_mnist_layers_5_1000_1_0.5_1.2_1.0_3/testacc.txt'])
print('NACA mnist 5layers:', a.max(), b[np.where(a==a.max())[0][0]])
# Out:
# 100
# NACA mnist 3layers: 96.54947916666667 0.005008012820510999
# 100
# NACA mnist 4layers: 96.42928685897436 0.045072115384620304
# 100
# NACA mnist 5layers: 95.68309294871796 0.040064102564109305

# %% [markdown]
# ### ANN

# %%
import numpy as np
import os
def Data(list_, *arg):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    Err = 100-data
    min_ = Err.min(1).max()
    max_ = Err.max(1).min()
    errlist = np.linspace(min_, max_, 5)
    epoch = data.shape[0]

    err = np.zeros((Err.shape[0], len(errlist)))
    for i in range(Err.shape[0]):
        for j in range(len(errlist)):
            err[i, j] = np.where(Err[i] >= errlist[j])[0][-1]
    mean_, std_ = err.mean(1).mean(), err.mean(1).std()/np.sqrt(5)
    return data.mean(0), data.std(0)

root = 'D:\\code\\EAST\\data\\new\\multilayers\\1000'
a, b = Data(['2022091722h17m34s_naca_ann_mnist_3_0_0.5_1.2/testacc.txt',
             '2022091722h17m34s_naca_ann_mnist_3_1_0.5_1.2/testacc.txt'])
print('NACA mni 3layers:', a.max(), b[np.where(a==a.max())[0][0]])
a, b = Data(['2022092010h02m44s_naca_ann_mnist_layers_4_1000_2_0.5_1.2/testacc.txt',
             '2022092010h02m44s_naca_ann_mnist_layers_4_1000_3_0.5_1.2/testacc.txt'])
print('NACA mni 4layers:', a.max(), b[np.where(a==a.max())[0][0]])
a, b = Data(['2022092010h03m09s_naca_ann_mnist_layers_5_1000_2_0.5_1.2/testacc.txt',
             '2022092010h03m09s_naca_ann_mnist_layers_5_1000_3_0.5_1.2/testacc.txt'])
print('NACA mni 5layers:', a.max(), b[np.where(a==a.max())[0][0]])
# Out:
# 100
# NACA mni 3layers: 96.2489983974359 0.0651041666666714
# 100
# NACA mni 4layers: 96.3641826923077 0.0400641025641022
# 100
# NACA mni 5layers: 96.33413461538461 0.030048076923080203

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter

def to_percent(temp, position):
    return '%1.0f'%(1*temp) + '%'

plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16

TID = np.array([96.83, 96.38, 96.14])
TID_err = np.array([0.162, 0.202, 0.284])
MNIST = np.array([96.55, 96.43, 96.68])
MNIST_err = np.array([0.01, 0.05, 0.04])

plt.bar([1-0.2, 1, 1+0.2], TID, width=0.2,yerr=TID_err, color=['C0','C1','C2'])
plt.errorbar([1-0.2, 1, 1+0.2],TID, fmt=" ",yerr=TID_err, xerr=0, capsize=7,color='black')
plt.bar([0-0.2, 0, 0+0.2],  MNIST, width=0.2,yerr=MNIST_err, color=['C0','C1','C2'])
plt.errorbar([0-0.2, 0, 0+0.2],MNIST, fmt=" ",yerr=MNIST_err, xerr=0, capsize=7,color='black')

plt.xticks([0,1],['MNIST', 'TIDigits'])
plt.ylim(80,100)
plt.savefig('Multi_layer_SNN.svg')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter

def to_percent(temp, position):
    return '%1.0f'%(1*temp) + '%'

plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16

TID = np.array([91.72, 92.00, 91.92])[::-1]
TID_err = np.array([0.08, 0.04, 0.20])[::-1]
MNIST = np.array([96.24, 96.36, 96.33])[::-1]
MNIST_err = np.array([0.07, 0.04, 0.03])[::-1]

plt.bar([1-0.2, 1, 1+0.2], TID, width=0.2,yerr=TID_err, color=['C0','C1','C2'])
plt.errorbar([1-0.2, 1, 1+0.2],TID, fmt=" ",yerr=TID_err, xerr=0, capsize=7,color='black')
plt.bar([0-0.2, 0, 0+0.2],  MNIST, width=0.2,yerr=MNIST_err, color=['C0','C1','C2'])
plt.errorbar([0-0.2, 0, 0+0.2],MNIST, fmt=" ",yerr=MNIST_err, xerr=0, capsize=7,color='black')

plt.xticks([0,1],['MNIST', 'TIDigits'])
plt.ylim(80,100)
plt.savefig('Multi_layer_ANN.svg')
plt.show()

# %% [markdown]
# ## Cost

# %%
def Data(list_,list_1,list_2, *arg):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data1 = np.array(data)

    length = []
    data = []
    for i in range(len(list_1)):
        file = np.loadtxt(os.path.join(root, list_1[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data2 = np.array(data)

    length = []
    data = []
    for i in range(len(list_2)):
        file = np.loadtxt(os.path.join(root, list_2[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data3 = np.array(data)

    Err1 = (100-data1).mean(0)
    Err2 = (100-data2).mean(0)
    Err3 = (100-data3).mean(0)
    
    data1 = 100 - data1
    data2 = 100 - data2
    data3 = 100 - data3

    max_ = min(Err1.max(), Err2.max(), Err3.max())
    min_ = max(Err1.min(), Err2.min(), Err3.min())

    print('Data:', max_, min_)

    # 1
    errlist = np.linspace(min_, max_, 5)
    print(errlist)
    epoch = data1.shape[0]
    err = np.zeros((len(errlist)))
    Err = []
    for i in range(len(list_)):
        for j in range(len(errlist)):
            try:
                err[j] = np.where(data1[i] >= errlist[j])[0][-1]
            except:
                err[j] = 0
        mean_, std_ = err.mean(), err.std()/np.sqrt(5)
        Err.append(mean_)
    print(arg[0]+':', np.array(Err).mean(), np.array(Err).std())
    # 2
    errlist = np.linspace(min_, max_, 5)
    epoch = data2.shape[0]
    err = np.zeros((len(errlist)))
    Err = []
    for i in range(len(list_)):
        for j in range(len(errlist)):
            try:
                err[j] = np.where(data2[i] >= errlist[j])[0][-1]
            except:
                err[j] = 0
        mean_, std_ = err.mean(), err.std()/np.sqrt(5)
        Err.append(mean_)
    print(arg[1]+':', np.array(Err).mean(), np.array(Err).std())
    # 3
    errlist = np.linspace(min_, max_, 5)
    epoch = data3.shape[0]
    err = np.zeros((len(errlist)))
    Err = []
    for i in range(len(list_)):
        for j in range(len(errlist)):
            try:
                err[j] = np.where(data3[i] >= errlist[j])[0][-1]
            except:
                err[j] = 0
        mean_, std_ = err.mean(), err.std()/np.sqrt(5)
        Err.append(mean_)
    print(arg[2]+':', np.array(Err).mean(), np.array(Err).std())
    return 

# SNN TID 
# NACA ErrNACA BRP
root = 'D:\\code\\EAST\\data\\new'
_ = Data(['2022091820h03m04s_naca_snn_tidigits_layers_3_0_0.5_1.2_0.1_3/testacc.txt',
             '2022091820h03m04s_naca_snn_tidigits_layers_3_1_0.5_1.2_0.1_3/testacc.txt'],
    ['2022092103h53m45s_naca_snn_tidigits_layers_4_1000_0_0.5_1.2_0.1_3/testacc.txt',
             '2022092103h53m45s_naca_snn_tidigits_layers_4_1000_1_0.5_1.2_0.1_3/testacc.txt'],
    ['2022092103h54m47s_naca_snn_tidigits_layers_5_1000_0_0.5_1.2_0.1_3/testacc.txt',
             '2022092103h54m47s_naca_snn_tidigits_layers_5_1000_1_0.5_1.2_0.1_3/testacc.txt'],
         '**SNN_TIDigits_NACA_3','***SNN_TIDigits_NACA_4','***SNN_TIDigits_NAC_5')

root = 'D:/code/EAST/data/new'
_ = Data(['2022091820h01m39s_naca_snn_mnist_layers_3_0_0.5_1.2_1.0_3/testacc.txt',
         '2022091820h01m39s_naca_snn_mnist_layers_3_1_0.5_1.2_1.0_3/testacc.txt'],
    ['2022092103h54m00s_naca_snn_mnist_layers_4_1000_0_0.5_1.2_1.0_3/testacc.txt',
             '2022092103h54m00s_naca_snn_mnist_layers_4_1000_1_0.5_1.2_1.0_3/testacc.txt'],
         ['2022092103h54m30s_naca_snn_mnist_layers_5_1000_0_0.5_1.2_1.0_3/testacc.txt',
             '2022092103h54m30s_naca_snn_mnist_layers_5_1000_1_0.5_1.2_1.0_3/testacc.txt']
         , '***SNN_MNIST_NACA_3','***SNN_MNIST_NACA_4','***SNN_MNIST_NAC_5')
# Out:
# 100
# 100
# 100
# Data: 48.9448051948052 3.855519480519483
# [ 3.85551948 15.12784091 26.40016234 37.67248377 48.94480519]
# **SNN_TIDigits_NACA_3: 19.6 0.7999999999999989
# ***SNN_TIDigits_NACA_4: 20.700000000000003 0.09999999999999964
# ***SNN_TIDigits_NAC_5: 21.5 0.10000000000000142
# 100
# 100
# 100
# Data: 8.378405448717949 4.316907051282051
# [4.31690705 5.33228165 6.34765625 7.36303085 8.37840545]
# ***SNN_MNIST_NACA_3: 4.0 0.40000000000000013
# ***SNN_MNIST_NACA_4: 9.7 0.2999999999999998
# ***SNN_MNIST_NAC_5: 25.0 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter

def to_percent(temp, position):
    return '%1.0f'%(1*temp) + '%'

plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16

weight = 30
cost_tid = [weight**2*1000 + 1000*10,
        weight**2*1000 + 1000 * 1000 + 1000*10,
        weight**2*1000 + 1000 * 1000 + 1000 * 1000 + 1000*10]
weight = 28
cost_mni = [weight**2*1000 + 1000*10,
        weight**2*1000 + 1000 * 1000 + 1000*10,
        weight**2*1000 + 1000 * 1000 + 1000 * 1000 + 1000*10]

TID = np.array([19.6, 20.7, 21.5]) * cost_tid
TID_err = np.array([0.8, 0.1, 0.1]) * cost_tid
MNIST = np.array([4, 9.7, 25]) * cost_mni
MNIST_err = np.array([0.4, 0.3, 0.0]) * cost_mni

plt.bar([1-0.2, 1, 1+0.2], TID, width=0.2,yerr=TID_err, color=['C0','C1','C2'])
plt.errorbar([1-0.2, 1, 1+0.2],TID, fmt=" ",yerr=TID_err, xerr=0, capsize=7,color='black')
plt.bar([0-0.2, 0, 0+0.2],  MNIST, width=0.2,yerr=MNIST_err, color=['C0','C1','C2'])
plt.errorbar([0-0.2, 0, 0+0.2],MNIST, fmt=" ",yerr=MNIST_err, xerr=0, capsize=7,color='black')

plt.xticks([0,1],['MNIST', 'TIDigits'])
plt.ylim(0,10*1e7)
plt.savefig('Multi_layer_SNN_cost.svg')
plt.show()

# %%
def Data(list_,list_1,list_2, *arg):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data1 = np.array(data)

    length = []
    data = []
    for i in range(len(list_1)):
        file = np.loadtxt(os.path.join(root, list_1[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data2 = np.array(data)

    length = []
    data = []
    for i in range(len(list_2)):
        file = np.loadtxt(os.path.join(root, list_2[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data3 = np.array(data)

    Err1 = (100-data1).mean(0)
    Err2 = (100-data2).mean(0)
    Err3 = (100-data3).mean(0)
    
    data1 = 100 - data1
    data2 = 100 - data2
    data3 = 100 - data3

    max_ = min(Err1.max(), Err2.max(), Err3.max())
    min_ = max(Err1.min(), Err2.min(), Err3.min())

    print('Data:', max_, min_)

    # 1
    errlist = np.linspace(min_, max_, 5)
    print(errlist)
    epoch = data1.shape[0]
    err = np.zeros((len(errlist)))
    Err = []
    for i in range(len(list_)):
        for j in range(len(errlist)):
            try:
                err[j] = np.where(data1[i] >= errlist[j])[0][-1]
            except:
                err[j] = 1
        mean_, std_ = err.mean(), err.std()/np.sqrt(5)
        Err.append(mean_)
    print(arg[0]+':', np.array(Err).mean(), np.array(Err).std())
    # 2
    errlist = np.linspace(min_, max_, 5)
    epoch = data2.shape[0]
    err = np.zeros((len(errlist)))
    Err = []
    for i in range(len(list_)):
        for j in range(len(errlist)):
            try:
                err[j] = np.where(data2[i] >= errlist[j])[0][-1]
            except:
                err[j] = 1
        mean_, std_ = err.mean(), err.std()/np.sqrt(5)
        Err.append(mean_)
    print(arg[1]+':', np.array(Err).mean(), np.array(Err).std())
    # 3
    errlist = np.linspace(min_, max_, 5)
    epoch = data3.shape[0]
    err = np.zeros((len(errlist)))
    Err = []
    for i in range(len(list_)):
        for j in range(len(errlist)):
            try:
                err[j] = np.where(data3[i] >= errlist[j])[0][-1]
            except:
                err[j] = 1
        mean_, std_ = err.mean(), err.std()/np.sqrt(5)
        Err.append(mean_)
    print(arg[2]+':', np.array(Err).mean(), np.array(Err).std())
    return 

root = 'D:\\code\\EAST\\data\\new\\multilayers\\1000'
_ = Data(['2022091722h18m06s_naca_ann_tidigits_3_0_0.5_1.2/testacc.txt',
     '2022091722h18m06s_naca_ann_tidigits_3_1_0.5_1.2/testacc.txt'],
    ['2022092010h02m56s_naca_ann_tidigits_layers_4_1000_2_0.5_1.2/testacc.txt',
             '2022092010h02m56s_naca_ann_tidigits_layers_4_1000_3_0.5_1.2/testacc.txt'],
    ['2022092010h03m02s_naca_ann_tidigits_layers_5_1000_2_0.5_1.2/testacc.txt',
             '2022092010h03m02s_naca_ann_tidigits_layers_5_1000_3_0.5_1.2/testacc.txt'], 
         '**ANN_TIDigits_NACA_3','***ANN_TIDigits_NACA_4','***ANN_TIDigits_NACA_5')

root = 'D:\\code\\EAST\\data\\new\\multilayers\\1000'
_ = Data(['2022091722h17m34s_naca_ann_mnist_3_0_0.5_1.2/testacc.txt',
             '2022091722h17m34s_naca_ann_mnist_3_1_0.5_1.2/testacc.txt'],
    ['2022092010h02m44s_naca_ann_mnist_layers_4_1000_2_0.5_1.2/testacc.txt',
             '2022092010h02m44s_naca_ann_mnist_layers_4_1000_3_0.5_1.2/testacc.txt'],
         ['2022092010h03m09s_naca_ann_mnist_layers_5_1000_2_0.5_1.2/testacc.txt',
             '2022092010h03m09s_naca_ann_mnist_layers_5_1000_3_0.5_1.2/testacc.txt']
         , '***ANN_MNIST_NACA_3','***ANN_MNIST_NACA_4','***ANN_MNIST_NACA_5')
# Out:
# 100
# 100
# 100
# Data: 67.57305194805195 8.279220779220779
# [ 8.27922078 23.10267857 37.92613636 52.74959416 67.57305195]
# **ANN_TIDigits_NACA_3: 21.2 0.1999999999999993
# ***ANN_TIDigits_NACA_4: 21.4 0.0
# ***ANN_TIDigits_NACA_5: 21.5 0.3000000000000007
# 100
# 100
# 100
# Data: 10.847355769230774 3.751001602564102
# [ 3.7510016   5.52509014  7.29917869  9.07326723 10.84735577]
# ***ANN_MNIST_NACA_3: 22.8 0.0
# ***ANN_MNIST_NACA_4: 20.3 2.3000000000000007
# ***ANN_MNIST_NACA_5: 22.2 1.1999999999999993

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter

def to_percent(temp, position):
    return '%1.0f'%(1*temp) + '%'

plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16

weight = 30
cost_tid = [weight**2*1000 + 1000*10,
        weight**2*1000 + 1000 * 1000 + 1000*10,
        weight**2*1000 + 1000 * 1000 + 1000 * 1000 + 1000*10]
weight = 28
cost_mni = [weight**2*1000 + 1000*10,
        weight**2*1000 + 1000 * 1000 + 1000*10,
        weight**2*1000 + 1000 * 1000 + 1000 * 1000 + 1000*10]

TID = np.array([21.2, 21.4, 21.5]) * cost_tid
TID_err = np.array([0.2, 0.0, 0.3]) * cost_tid
MNIST = np.array([22.8, 20.3, 22.2]) * cost_mni
MNIST_err = np.array([0.0, 2.3, 1.2]) * cost_mni

plt.bar([1-0.2, 1, 1+0.2], TID, width=0.2,yerr=TID_err, color=['C0','C1','C2'])
plt.errorbar([1-0.2, 1, 1+0.2],TID, fmt=" ",yerr=TID_err, xerr=0, capsize=7,color='black')
plt.bar([0-0.2, 0, 0+0.2],  MNIST, width=0.2,yerr=MNIST_err, color=['C0','C1','C2'])
plt.errorbar([0-0.2, 0, 0+0.2],MNIST, fmt=" ",yerr=MNIST_err, xerr=0, capsize=7,color='black')

plt.xticks([0,1],['MNIST', 'TIDigits'])
plt.ylim(0,1*1e8)
plt.savefig('Multi_layer_ANN_cost.svg')
plt.show()

# %% [markdown]
# # P - value

# %%
from scipy.stats import ttest_ind,norm,f
import numpy as np
def ftest(s1,s2):
    '''F-test'''
    F = np.var(s1)/np.var(s2)
    v1 = len(s1) - 1
    v2 = len(s2) - 1
    p_val = 1 - 2*abs(0.5-f.cdf(F,v1,v2))
    if p_val < 0.05:
        equal_var=False
    else:
        equal_var=True
    return equal_var
         
def ttest_ind_fun(s1,s2):
    '''t-test'''
    equal_var = ftest(s1,s2)
    ttest,pval = ttest_ind(s1,s2,equal_var=equal_var)
    return pval

xx = []
for i in range(10000):
    np.random.seed(i)

    mean = [99.03,98.69]
    std = [0.06,0.14]

    s1 = norm.rvs(loc=mean[0],scale=std[0],size=5)
    s2 = norm.rvs(loc=mean[1],scale=std[1],size=5)
    xx.append(ttest_ind_fun(s1,s2))
np.array(xx).mean()
# Out:
# 0.006739973313098315

# %% [markdown]
# # Classification (uniform, normal, beta)

# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from matplotlib.ticker import FuncFormatter
import xlrd

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

def plot(list_, *args):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    plt.plot(np.arange(data.shape[1])+1, data.mean(0), color=args[1], label=args[0], linewidth=3)
    plt.fill_between(np.arange(data.shape[1])+1, data.mean(0)-data.std(0)*0.5, data.mean(0)+data.std(0)*0.5, color=args[1], alpha=.1)
    print(args[0]+'_max:', data.mean(0).max(), data.std(0)[np.where(data.mean(0)==data.mean(0).max())[0][0]])

def Data(list_):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length)
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    return data.mean(0), data.std(0)

# NACA
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16
root = 'D:/code/EAST/data/new'
plot(['2022091505h05m24s_naca_snn_mnist_0_0.5_1.2_1.0_3/testacc.txt',
     '2022091505h05m24s_naca_snn_mnist_1_0.5_1.2_1.0_3/testacc.txt',
     '2022091505h05m24s_naca_snn_mnist_2_0.5_1.2_1.0_3/testacc.txt',
      '2022091505h05m24s_naca_snn_mnist_3_0.5_1.2_1.0_3/testacc.txt',
      '2022091505h05m24s_naca_snn_mnist_4_0.5_1.2_1.0_3/testacc.txt'], 'Uniform', 'C1')
root = 'D:/code/EAST/data/new'
plot([
    '2022091800h50m52s_naca_snn_normal_0_0.5_1.2_1.0_3/testacc.txt',
    '2022091800h50m53s_naca_snn_normal_1_0.5_1.2_1.0_3/testacc.txt',
    '2022091800h50m52s_naca_snn_normal_2_0.5_1.2_1.0_3/testacc.txt',
    '2022091800h50m52s_naca_snn_normal_3_0.5_1.2_1.0_3/testacc.txt',
    '2022091800h50m53s_naca_snn_normal_4_0.5_1.2_1.0_3/testacc.txt'], 'Normal', 'C0')
root = 'D:/code/EAST/data/new'
plot([
    '2022091800h51m15s_naca_snn_beta_0_0.5_1.2_1.0_3/testacc.txt',
    '2022091800h51m15s_naca_snn_beta_1_0.5_1.2_1.0_3/testacc.txt',
    '2022091800h51m15s_naca_snn_beta_2_0.5_1.2_1.0_3/testacc.txt',
    '2022091800h51m15s_naca_snn_beta_3_0.5_1.2_1.0_3/testacc.txt',
    '2022091800h51m15s_naca_snn_beta_4_0.5_1.2_1.0_3/testacc.txt',
    ], 'Beta', 'C2')

root = 'D:/code/github_for_EAST/Local_version_nopublised20220923/plot/data'
plot([
    '2023051820h42m08s_Default_0_0.5_1.2_1/testacc.txt',
    ], 'Conv-Conv-Fc-Fc', 'C3')

root = 'D:/code/github_for_EAST/Local_version_nopublised20220923/plot/data'
plot([
    '2023052018h23m35s_normal_0_0.5_1.2_1/testacc.txt',
    ], 'Conv-Fc-Fc', 'C3')

root = 'D:/code/github_for_EAST/Local_version_nopublised20220923/plot/data'
plot([
    '2023052018h13m39s_normal_0_0.5_1.2_1/testacc.txt',
    ], 'Fc-Fc', 'C3')

plt.ylim([90,100])
plt.xlim([0,50])
plt.legend(loc='lower right')
plt.savefig('mnist_distribution.svg')
plt.show()
# Out:
# 100
# Uniform_max: 99.03044871794872 0.06022955279796566
# 100
# Normal_max: 98.84415064102565 0.1593272341758667
# 100
# Beta_max: 98.82211538461539 0.16910183966670916
# 100
# Conv-Conv-Fc-Fc_max: 99.08854166666667 0.0
# 100
# Conv-Fc-Fc_max: 97.63621794871794 0.0
# 100
# Fc-Fc_max: 96.43429487179488 0.0

# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from matplotlib.ticker import FuncFormatter
import xlrd

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

def plot(list_, *args):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[10])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    plt.plot(np.arange(data.shape[1])+1, data.mean(0), color=args[1], label=args[0], linewidth=3, alpha=args[2])
    plt.fill_between(np.arange(data.shape[1])+1, data.mean(0)-data.std(0)*0.5, data.mean(0)+data.std(0)*0.5, color=args[1], alpha=.1)
    print(args[0]+'_max:', data.mean(0).max(), data.std(0)[np.where(data.mean(0)==data.mean(0).max())[0][0]])

def Data(list_):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length)
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    return data.mean(0), data.std(0)

# NACA
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16
fig, ax1 = plt.subplots(figsize=(5,3))
root = 'D:/code/EAST/data/new'
plot(['2022091505h05m24s_naca_snn_mnist_0_0.5_1.2_1.0_3/testacc.txt',
     '2022091505h05m24s_naca_snn_mnist_1_0.5_1.2_1.0_3/testacc.txt',
     '2022091505h05m24s_naca_snn_mnist_2_0.5_1.2_1.0_3/testacc.txt',
      '2022091505h05m24s_naca_snn_mnist_3_0.5_1.2_1.0_3/testacc.txt',
      '2022091505h05m24s_naca_snn_mnist_4_0.5_1.2_1.0_3/testacc.txt'], 'Uniform \n(Conv-Conv-FC-FC)', 'C1',0.6)
# root = 'D:/code/EAST/data/new'
# plot([
#     '2022091800h50m52s_naca_snn_normal_0_0.5_1.2_1.0_3/testacc.txt',
#     '2022091800h50m53s_naca_snn_normal_1_0.5_1.2_1.0_3/testacc.txt',
#     '2022091800h50m52s_naca_snn_normal_2_0.5_1.2_1.0_3/testacc.txt',
#     '2022091800h50m52s_naca_snn_normal_3_0.5_1.2_1.0_3/testacc.txt',
#     '2022091800h50m53s_naca_snn_normal_4_0.5_1.2_1.0_3/testacc.txt'], 'Normal', 'C0')
# root = 'D:/code/EAST/data/new'
# plot([
#     '2022091800h51m15s_naca_snn_beta_0_0.5_1.2_1.0_3/testacc.txt',
#     '2022091800h51m15s_naca_snn_beta_1_0.5_1.2_1.0_3/testacc.txt',
#     '2022091800h51m15s_naca_snn_beta_2_0.5_1.2_1.0_3/testacc.txt',
#     '2022091800h51m15s_naca_snn_beta_3_0.5_1.2_1.0_3/testacc.txt',
#     '2022091800h51m15s_naca_snn_beta_4_0.5_1.2_1.0_3/testacc.txt',
#     ], 'Beta', 'C2')

# root = 'D:/code/github_for_EAST/Local_version_nopublised20220923/plot/data'
# plot([
#     '2023051820h42m08s_Default_0_0.5_1.2_1/testacc.txt',
#     ], 'Conv-Conv-FC-FC', 'C4')

root = 'D:/code/github_for_EAST/Local_version_nopublised20220923/plot/data'
plot([
    '2023052018h23m35s_normal_0_0.5_1.2_1/testacc.txt',
    '2023052411h33m53s_normal_c_c_f_1_0.5_1.2_1/testacc.txt',
    '2023052411h34m10s_normal_c_c_f_2_0.5_1.2_1/testacc.txt',
    '2023052411h34m36s_normal_c_c_f_3_0.5_1.2_1/testacc.txt',
    '2023052411h34m44s_normal_c_c_f_4_0.5_1.2_1/testacc.txt'
    ], 'Uniform \n(Conv-FC-FC)', 'C1', 0.4)

root = 'D:/code/github_for_EAST/Local_version_nopublised20220923/plot/data'
plot([
    '2023052018h13m39s_normal_0_0.5_1.2_1/testacc.txt',
    '2023052411h35m12s_normal_f_f_1_0.5_1.2_1/testacc.txt',
    '2023052411h35m20s_normal_f_f_2_0.5_1.2_1/testacc.txt',
    '2023052411h35m27s_normal_f_f_3_0.5_1.2_1/testacc.txt',
    '2023052411h36m39s_normal_f_f_4_0.5_1.2_1/testacc.txt'
    ], 'Uniform \n(FC-FC)', 'C1', 0.2)

root = 'D:/code/github_for_EAST/Local_version_nopublised20220923/plot/data'
plot([
    '2023052411h38m14s_normal_c_c_f_f_f_0_0.5_1.2_1/testacc.txt',
    '2023052411h38m29s_normal_c_c_f_f_f_1_0.5_1.2_1/testacc.txt',
    '2023052411h38m43s_normal_c_c_f_f_f_2_0.5_1.2_1/testacc.txt',
    '2023052411h38m50s_normal_c_c_f_f_f_3_0.5_1.2_1/testacc.txt',
    '2023052416h25m15s_normal_c_c_f_f_f_5_0.5_1.2_1/testacc.txt'
    ], 'Uniform \n(FC-FC)', 'C1', 1)

plt.ylim([90,100])
plt.xlim([0,10])
plt.yticks([90,94,98])
# plt.legend(loc='lower right')
plt.savefig('mnist_distribution_1.svg')
plt.show()
# Out:
# 10
# Uniform
# (Conv-Conv-FC-FC)_max: 98.23317307692307 0.19345195762031853
# 10
# Uniform
# (Conv-FC-FC)_max: 97.39182692307693 0.22660137407659176
# 10
# Uniform
# (FC-FC)_max: 95.46073717948717 0.1741060704137887
# 10
# Uniform
# (FC-FC)_max: 98.1610576923077 0.21262302704864422

# %% [markdown]
# # Rank

# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from matplotlib.ticker import FuncFormatter
import xlrd

def to_percent(temp, position):
    return '%1.0f'%(temp) + '%'

def plot(list_, *args):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length+[100])
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    plt.plot(np.arange(data.shape[1])+1, data.mean(0), color=args[1], label=args[0], linewidth=3)
    plt.fill_between(np.arange(data.shape[1])+1, data.mean(0)-data.std(0)*0.5, data.mean(0)+data.std(0)*0.5, color=args[1], alpha=.1)
    print(args[0]+'_max:', data.mean(0).max(), data.std(0)[np.where(data.mean(0)==data.mean(0).max())[0][0]])

def Data(list_):
    length = []
    data = []
    for i in range(len(list_)):
        file = np.loadtxt(os.path.join(root, list_[i]))
        data.append(file[:,1])
        length.append(file[:,1].shape[0])
    max_length = min(length)
    print(max_length)
    for i in range(len(data)):
        data[i]=data[i][:max_length]
    data = np.array(data)
    return data.mean(0), data.std(0)

# NACA
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 16
root = 'D:\\code\\EAST\\data\\new\\multilayers'
plot(['2022091805h01m49s_naca_snn_rank01_0_0.5_1.2_1.0_3/testacc.txt',
     '2022091805h01m49s_naca_snn_rank01_1_0.5_1.2_1.0_3/testacc.txt'], 'Rank01', 'C0')
root = 'D:\\code\\EAST\\data\\new\\multilayers'
plot(['2022091805h01m58s_naca_snn_rank03_0_0.5_1.2_1.0_3/testacc.txt',
     '2022091805h01m58s_naca_snn_rank03_1_0.5_1.2_1.0_3/testacc.txt'], 'Rank03', 'C1')
root = 'D:\\code\\EAST\\data\\new\\multilayers'
plot(['2022091805h02m10s_naca_snn_rank05_0_0.5_1.2_1.0_3/testacc.txt',
     '2022091805h02m10s_naca_snn_rank05_1_0.5_1.2_1.0_3/testacc.txt'], 'Rank05', 'C2')
root = 'D:\\code\\EAST\\data\\new\\multilayers'
plot(['2022091805h02m13s_naca_snn_rank07_0_0.5_1.2_1.0_3/testacc.txt',
     '2022091805h02m13s_naca_snn_rank07_1_0.5_1.2_1.0_3/testacc.txt'], 'Rank07', 'C3')
root = 'D:\\code\\EAST\\data\\new\\multilayers'
plot(['2022091805h02m45s_naca_snn_rank09_0_0.5_1.2_1.0_3/testacc.txt',
     '2022091805h03m58s_naca_snn_rank09_1_0.5_1.2_1.0_3/testacc.txt'], 'Rank09', 'C4')

plt.ylim([0,100])
plt.xlim([0,50])
plt.legend(loc='lower left')
plt.savefig('rank.svg')
plt.show()
# Out:
# 100
# Rank01_max: 10.58193108974359 0.7662259615384617
# 100
# Rank03_max: 92.70332532051282 0.776241987179489
# 92
# Rank05_max: 95.98858173076923 0.4457131410256423
# 91
# Rank07_max: 99.11358173076923 0.015024038461540101
# 90
# Rank09_max: 99.08353365384616 0.015024038461540101
